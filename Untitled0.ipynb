# %% [markdown]
# <a href="https://colab.research.google.com/github/MINA26HR/TestRepo_01/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("/content/drive/Shareddrives/MiNA2026HR/inventory.csv")
data

# data2 = pd.read_csv("/content/drive/Shareddrives/MINA2026KM4/Advertising.csv")
# data2
# Out:
#    E1  Electronics   Phone   10   699.99          24
# 0  E2  Electronics  Laptop    5  1099.99          12
# 1  G1      Grocery   Apple  100     0.99  2026-06-01
# 2  G2      Grocery    Milk   30     1.49  2026-06-01
